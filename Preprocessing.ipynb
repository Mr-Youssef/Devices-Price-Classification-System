# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ### Loading the Data

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import pickle

df = pd.read_excel("Dataset/train.xlsx")

print("Number of records: ", len(df))
# Out:
# Number of records:  2000

# %%
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim    fc  four_g  int_memory  \
# 0            842     0          2.2         0   1.0     0.0         7.0
# 1           1021     1          0.5         1   0.0     1.0        53.0
# 2            563     1          0.5         1   2.0     1.0        41.0
# 3            615     1          2.5         0   0.0     0.0        10.0
# 4           1821     1          1.2         0  13.0     1.0        44.0
#
#    m_dep  mobile_wt  n_cores  ...  px_height  px_width     ram  sc_h  sc_w  \
# 0    0.6      188.0      2.0  ...       20.0     756.0  2549.0   9.0   7.0
# 1    0.7      136.0      3.0  ...      905.0    1988.0  2631.0  17.0   3.0
# 2    0.9      145.0      5.0  ...     1263.0    1716.0  2603.0  11.0   2.0
# 3    0.8      131.0      6.0  ...     1216.0    1786.0  2769.0  16.0   8.0
# 4    0.6      141.0      2.0  ...     1208.0    1212.0  1411.0   8.0   2.0
#
#    talk_time  three_g  touch_screen  wifi  price_range
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             1995 non-null   float64
#  5   four_g         1995 non-null   float64
#  6   int_memory     1995 non-null   float64
#  7   m_dep          1995 non-null   float64
#  8   mobile_wt      1996 non-null   float64
#  9   n_cores        1996 non-null   float64
#  10  pc             1995 non-null   float64
#  11  px_height      1996 non-null   float64
#  12  px_width       1998 non-null   float64
#  13  ram            1998 non-null   float64
#  14  sc_h           1999 non-null   float64
#  15  sc_w           1999 non-null   float64
#  16  talk_time      2000 non-null   int64
# ...

# %% [markdown]
# ### Observation:
# #### Notice that all features are numerical features which is easier to deal with.

# %% [markdown]
# ### Handling Missing Values

# %%
print("Total number of null values: ", df.isnull().sum().sum())
print("\nCount of null values per feature: ")
print(df.isnull().sum())
# Out:
# Total number of null values:  43
#
# Count of null values per feature:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               5
# four_g           5
# int_memory       5
# m_dep            5
# mobile_wt        4
# n_cores          4
# pc               5
# px_height        4
# px_width         2
# ram              2
# sc_h             1
# sc_w             1
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %% [markdown]
# ### Observation:
# #### The biggest number of missing values in a feature is 5

# %% [markdown]
# ### Conclusion:
#
# #### Since number of nulls is minimal, we can safely drop them

# %%
# Drop the rows with null values
df = df.dropna()
print("Number of records after dropping nulls: ", len(df))
# Out:
# Number of records after dropping nulls:  1991

# %% [markdown]
# ### Handling Duplicates

# %%
# Checking for duplicates
df.duplicated().sum()
# No duplicates found
# Out:
# 0

# %% [markdown]
# ### Showing some statistics

# %%
df.describe()
# Out:
#        battery_power         blue  clock_speed     dual_sim           fc  \
# count    1991.000000  1991.000000  1991.000000  1991.000000  1991.000000
# mean     1238.270718     0.496233     1.522451     0.510799     4.307885
# std       439.641057     0.500111     0.815499     0.500009     4.339735
# min       501.000000     0.000000     0.500000     0.000000     0.000000
# 25%       851.500000     0.000000     0.700000     0.000000     1.000000
# 50%      1225.000000     0.000000     1.500000     1.000000     3.000000
# 75%      1615.500000     1.000000     2.200000     1.000000     7.000000
# max      1998.000000     1.000000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  1991.000000  1991.000000  1991.000000  1991.000000  1991.000000  ...
# mean      0.520844    32.074335     0.502009   140.263184     4.516323  ...
# std       0.499691    18.138177     0.288622    35.398777     2.291257  ...
# ...

# %% [markdown]
# ### Observation
# #### Notice that the features have different ranges. Therefore, we need to normalize them.

# %% [markdown]
# ### Features Normalization

# %%
# Normalizing the data except the last column (price_range which is the target)
scaler = MinMaxScaler()
df.iloc[:, :-1] = scaler.fit_transform(df.iloc[:, :-1])
df.head()       # Checking the data after normalization
# Out:
#    battery_power  blue  clock_speed  dual_sim        fc  four_g  int_memory  \
# 0       0.227789     0         0.68         0  0.052632     0.0    0.080645
# 1       0.347361     1         0.00         1  0.000000     1.0    0.822581
# 2       0.041416     1         0.00         1  0.105263     1.0    0.629032
# 3       0.076152     1         0.80         0  0.000000     0.0    0.129032
# 4       0.881764     1         0.28         0  0.684211     1.0    0.677419
#
#       m_dep  mobile_wt   n_cores  ...  px_height  px_width       ram  \
# 0  0.555556   0.900000  0.142857  ...   0.010204  0.170895  0.612774
# 1  0.666667   0.466667  0.285714  ...   0.461735  0.993324  0.634687
# 2  0.888889   0.541667  0.571429  ...   0.644388  0.811749  0.627205
# 3  0.777778   0.425000  0.714286  ...   0.620408  0.858478  0.671566
# 4  0.555556   0.508333  0.142857  ...   0.616327  0.475300  0.308658
#
#        sc_h      sc_w  talk_time  three_g  touch_screen  wifi  price_range
# ...

# %%
# Saving the scaler for later use
pickle.dump(scaler, open('GeneratedFiles/scaler.pkl', "wb"))

# %%
# Checking the distribution of the target
df.value_counts('price_range')
# Out:
# price_range
# 0    499
# 2    499
# 3    497
# 1    496
# Name: count, dtype: int64

# %% [markdown]
# ### Observation:
# #### The dataset is balanced as the distribution of the target values is almost equal

# %% [markdown]
# ### Saving the data

# %%
df.to_excel('Dataset/PreprocessedTrain.xlsx', index=False)
